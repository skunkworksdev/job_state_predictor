# %% [markdown]
# <a href="https://colab.research.google.com/github/TXH2020/job_state_predictor/blob/main/Slurm_JSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download dataset
# !wget https://data.nrel.gov/system/files/152/1711670203-anon_jobs_2019-12.json.bz2
# !bzip2 -d 1711670203-anon_jobs_2019-12.json.bz2
#!wget https://data.nrel.gov/system/files/152/1711670203-anon_jobs_2020-04.json.bz2
#!bzip2 -d 1711670203-anon_jobs_2020-04.json.bz2
#!wget https://data.nrel.gov/system/files/152/1711670203-anon_jobs_2020-08.json.bz2
#!bzip2 -d 1711670203-anon_jobs_2020-08.json.bz2
# Out:
# --2025-04-05 17:19:16--  https://data.nrel.gov/system/files/152/1711670203-anon_jobs_2019-12.json.bz2
# Resolving data.nrel.gov (data.nrel.gov)... 76.223.107.85, 13.248.240.147
# Connecting to data.nrel.gov (data.nrel.gov)|76.223.107.85|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# The above cell would create a JSON file
# Directly calling pandas read_json doesnt seem to work (some length mismatch error)
# json.load on the File object throws extra data error.
# Parse the JSON line by line
import json
jobs = []


with open('1711670203-anon_jobs_2019-12.json', 'r') as f:
#with open('1711670203-anon_jobs_2020-04.json', 'r') as f:
#with open('1711670203-anon_jobs_2020-08.json', 'r') as f:
  for job in f:
    jobs.append(json.loads(job))

jobs[:5]
# Out:
# [{'end_time': '2019-12-04T16:17:00.000Z',
#   'script': 'FF126399B6D8',
#   'avg_power': 216.58333,
#   'processors_req': 2,
#   'account': 'CA2FCF3FAD85',
#   'nodelist': ['r2i5n12', 'r2i5n13'],
#   'array_pos': None,
#   'nodes_used': 2,
#   'wallclock_used': 'P0DT0H6M53S',
#   'cpu_used': 'P0DT8H15M36S',
#   'submit_time': '2019-12-04T16:10:02.000Z',
#   'processors_used': 72,
#   'nodes_req': 2,
#   'partition': 'csc',
#   'start_time': '2019-12-04T16:10:07.000Z',
#   'std_power': 0.51492864,
#   'user': '9034779C0D76',
#   'qos': 'normal',
#   'job_id': 1852149,
#   'wallclock_req': 'P0DT0H30M0S',
#   'state': 'FAILED',
#   'queue_wait': 'P0DT0H0M5S'},
#  {'end_time': '2019-12-27T08:46:36.000Z',
#   'script': 'A321CB1B6D58',
#   'avg_power': 224.92857,
#   'processors_req': 1,
#   'account': '4E8A31C3E777',
#   'nodelist': ['r8i0n28'],
#   'array_pos': None,
#   'nodes_used': 1,
#   'wallclock_used': 'P0DT0H55M37S',
#   'cpu_used': 'P1DT9H22M12S',
# ...

# %%
columns = ['job_id', 'user', 'account', 'script', 'qos', 'array_pos',
           'partition', 'submit_time', 'start_time', 'queue_wait', 'end_time',
           'processors_req', 'processors_used', 'nodes_req', 'nodes_used',
           'nodelist', 'wallclock_req', 'wallclock_used', 'cpu_used',
           'std_power', 'avg_power',  'state']

# Create an array of jobs.
# Each job is a list containing the above fields in the same order
jobs_array = []
for job in jobs:
  job_details = []
  for column in columns:
    if column in job.keys():
      job_details.append(job[column])
    else:
      job_details.append(None)
  jobs_array.append(job_details)

jobs_array[:5]
# Out:
# [[1852149,
#   '9034779C0D76',
#   'CA2FCF3FAD85',
#   'FF126399B6D8',
#   'normal',
#   None,
#   'csc',
#   '2019-12-04T16:10:02.000Z',
#   '2019-12-04T16:10:07.000Z',
#   'P0DT0H0M5S',
#   '2019-12-04T16:17:00.000Z',
#   2,
#   72,
#   2,
#   2,
#   ['r2i5n12', 'r2i5n13'],
#   'P0DT0H30M0S',
#   'P0DT0H6M53S',
#   'P0DT8H15M36S',
#   0.51492864,
#   216.58333,
#   'FAILED'],
#  [2132803,
#   '538894D70272',
#   '4E8A31C3E777',
#   'A321CB1B6D58',
#   'high',
#   None,
#   'standard',
#   '2019-12-27T07:50:44.000Z',
#   '2019-12-27T07:50:59.000Z',
#   'P0DT0H0M15S',
#   '2019-12-27T08:46:36.000Z',
#   1,
#   36,
#   1,
#   1,
#   ['r8i0n28'],
#   'P2DT0H0M0S',
#   'P0DT0H55M37S',
#   'P1DT9H22M12S',
#   0.2598701,
#   224.92857,
#   'FAILED'],
#  [1939677,
#   'B6BF2D0A9DD5',
#   '281BDCFA733D',
#   '7BEFEAE2423F',
#   'normal',
#   None,
#   'gpu',
#   '2019-12-11T10:58:48.000Z',
#   '2019-12-11T16:44:31.000Z',
#   'P0DT5H45M43S',
#   '2019-12-12T04:54:48.000Z',
#   4,
#   72,
# ...

# %%
import pandas as pd


jobs_df = pd.DataFrame(data=jobs_array, columns=columns)
jobs_df.head()
# Out:
#     job_id          user       account        script      qos  array_pos  \
# 0  1852149  9034779C0D76  CA2FCF3FAD85  FF126399B6D8   normal        NaN
# 1  2132803  538894D70272  4E8A31C3E777  A321CB1B6D58     high        NaN
# 2  1939677  B6BF2D0A9DD5  281BDCFA733D  7BEFEAE2423F   normal        NaN
# 3  1982669  B6BF2D0A9DD5  281BDCFA733D  7BEFEAE2423F   normal        NaN
# 4  1844673  23D3EBCDD8DB  EFF4CEEC9899  261D1C12EF14  standby        NaN
#
#   partition               submit_time                start_time    queue_wait  \
# 0       csc  2019-12-04T16:10:02.000Z  2019-12-04T16:10:07.000Z    P0DT0H0M5S
# 1  standard  2019-12-27T07:50:44.000Z  2019-12-27T07:50:59.000Z   P0DT0H0M15S
# 2       gpu  2019-12-11T10:58:48.000Z  2019-12-11T16:44:31.000Z  P0DT5H45M43S
# 3       gpu  2019-12-12T17:53:07.000Z  2019-12-13T10:56:27.000Z  P0DT17H3M20S
# 4     short  2019-12-02T16:46:36.000Z  2019-12-02T16:47:11.000Z   P0DT0H0M35S
#
# ...

# %%
# user, account and script columns are anonymized.
# Find the value counts for these columns.
# If all the values in these columns are distinct, they are useless

for column in ['user', 'account', 'script']:
  print("\nValue count for ",column)
  print(jobs_df[column].value_counts())
# Out:
# Value count for  user
# user
# D4C5F119F377    62724
# 86DC976C3B41    41652
# D06D45534E9C    13299
# EC045FDC6F81     5977
# 23D3EBCDD8DB     4358
#                 ...
# 3FE5B469CAE5        1
# 11FB943B5342        1
# A686EA8EE7EC        1
# D317D6288D8E        1
# 8B81A41EE2EB        1
# Name: count, Length: 194, dtype: int64
#
# Value count for  account
# account
# 61DAA96FD9AB    64549
# 296433904850    18611
# DD758880753A    18364
# 8946FE16398B    15910
# 916BB2FB0DD6     7689
#                 ...
# 6262221A844D        1
# 018835D104A3        1
# CB0B29E4D7EC        1
# A91A532E2FA7        1
# 2558F777A492        1
# Name: count, Length: 133, dtype: int64
#
# Value count for  script
# script
# 5D1E964B35FE    102995
# F016C3DC42D5      3715
# 531E66DBC5B0      3016
# 17F80EE0E40A      1757
# 6658FAD9282E      1682
#                  ...
# DD5D10B6E1BE         1
# C9D03257BB2D         1
# 6BB5C5B146E6         1
# 4575B22EEC5C         1
# BF9BCC2A9253         1
# ...

# %%
# It is evident from above that script is not a useful column (41658 distinct values).
# Job ID is also useless, since its unique for every job.
# Hence, drop these two columns

jobs_df.drop(columns=['job_id', 'script'], inplace=True)
jobs_df.shape
# Out:
# (181503, 20)

# %%
# Convert submit_time, start time and end_time to datetime columns.
jobs_df['submit_time'] = pd.to_datetime(jobs_df['submit_time'])
jobs_df['start_time'] = pd.to_datetime(jobs_df['start_time'])
jobs_df['end_time'] = pd.to_datetime(jobs_df['end_time'])

# %%
# Find 25, 50, 75 percentiles and the mean of the run time.
run_time = jobs_df['end_time'] - jobs_df['start_time']
run_time.quantile(0.25), run_time.quantile(0.5), run_time.quantile(0.75), run_time.mean()
# Out:
# (Timedelta('0 days 00:18:33'),
#  Timedelta('0 days 00:31:30'),
#  Timedelta('0 days 01:21:01'),
#  Timedelta('0 days 03:25:48.145264816'))

# %%
# Check if nodes requested = nodes used.
# If shape for the below code is 0,19, above condition will hold true.

jobs_df[jobs_df['nodes_req'] != jobs_df['nodes_used']].shape
# Out:
# (3649, 20)

# %%
# Above condition does not hold true.
# This is because users might have specified a greater number of tasks than the available number of CPUs on the node.

# First, find the jobs where only one node has been used.
# Second, find the value counts for the processors_used column.
# If there is only one value, it mostly means that the each node has the same number of processors.

one_node_jobs = jobs_df[jobs_df['nodes_used'] == 1]
one_node_jobs['processors_used'].value_counts()
# Out:
# processors_used
# 36       169413
# 36864         1
# Name: count, dtype: int64

# %%
# There are very few jobs that are allocated a node with a different number of processors. Let's analyze this record.

one_node_jobs[one_node_jobs['processors_used'] == 36864]
# Out:
#                user       account     qos  array_pos partition  \
# 72238  C7F8C95DCCBF  CA2FCF3FAD85  normal        NaN       csc
#
#                     submit_time                start_time   queue_wait  \
# 72238 2019-12-04 16:15:45+00:00 2019-12-04 16:17:08+00:00  P0DT0H1M23S
#
#                        end_time  processors_req  processors_used  nodes_req  \
# 72238 2019-12-04 16:29:42+00:00            1024            36864          1
#
#        nodes_used                                           nodelist  \
# 72238           1  [r1i0n3, r1i0n4, r1i0n5, r1i0n6, r1i0n7, r1i0n...
#
#       wallclock_req wallclock_used         cpu_used  std_power  avg_power  \
# 72238   P0DT0H40M0S   P0DT0H12M34S  P321DT16H57M36S  35.400253  225.28345
#
#            state
# 72238  COMPLETED

# %%
# We need to check the length of the nodelist.

len(one_node_jobs[one_node_jobs['processors_used'] == 36864]['nodelist'].iloc[0])
# Out:
# 1024

# %%
# In above case, the number of processors = 1024 * 36.
# There's a chance that somehow, these jobs got nodes_used incorrectly as 1.
# Let's verify if nodes_used is always equal to the length of nodelist.

nodelist_length = jobs_df['nodelist'].apply(lambda x: len(x))
jobs_df[jobs_df['nodes_used'] != nodelist_length].shape
# Out:
# (1, 20)

# %%
# As expected, very few jobs have got it wrong.
# We can correct those job's values.
# After changing, check whether the change is done.

incorrect_job_index = jobs_df[jobs_df['processors_used'] == 36864].index
jobs_df.loc[incorrect_job_index, ['nodes_used']] = 1024
nodelist_length = jobs_df['nodelist'].apply(lambda x: len(x))
jobs_df[jobs_df['nodes_used'] != nodelist_length].shape
# Out:
# (0, 20)

# %%
# Now, check whether processors_used = 36 * nodes_used

calculated_processors_used = jobs_df['nodes_used'].apply(lambda x: 36 * x)
jobs_df[jobs_df['processors_used'] != calculated_processors_used].shape
# Out:
# (0, 20)

# %%
# Above condition holds true. We can drop processors_used.
# Check value_counts of array_pos.

jobs_df['array_pos'].value_counts()
# Out:
# array_pos
# 1.0      56
# 5.0      52
# 6.0      52
# 8.0      52
# 3.0      52
#          ..
# 189.0     5
# 199.0     5
# 193.0     5
# 196.0     5
# 200.0     5
# Name: count, Length: 200, dtype: int64

# %%
# We can't drop array_pos as it contains a decent number of values.
# Let's check if nodes_req is the same as processors_req

jobs_df[jobs_df['processors_req'] != jobs_df['nodes_req']].shape
# Out:
# (45973, 20)

# %%
# Since above condition does not hold true, analyze.

df_subset = jobs_df[jobs_df['processors_req'] != jobs_df['nodes_req']]
df_subset.head()
# Out:
#            user       account      qos  array_pos partition  \
# 2  B6BF2D0A9DD5  281BDCFA733D   normal        NaN       gpu
# 3  B6BF2D0A9DD5  281BDCFA733D   normal        NaN       gpu
# 4  23D3EBCDD8DB  EFF4CEEC9899  standby        NaN     short
# 5  23A0AEE781F6  EF8C83502275  standby        NaN     short
# 6  23D3EBCDD8DB  EFF4CEEC9899  standby        NaN     short
#
#                 submit_time                start_time    queue_wait  \
# 2 2019-12-11 10:58:48+00:00 2019-12-11 16:44:31+00:00  P0DT5H45M43S
# 3 2019-12-12 17:53:07+00:00 2019-12-13 10:56:27+00:00  P0DT17H3M20S
# 4 2019-12-02 16:46:36+00:00 2019-12-02 16:47:11+00:00   P0DT0H0M35S
# 5 2019-12-11 12:36:55+00:00 2019-12-11 12:37:38+00:00   P0DT0H0M43S
# 6 2019-12-02 16:46:38+00:00 2019-12-02 16:47:11+00:00   P0DT0H0M33S
#
#                    end_time  processors_req  processors_used  nodes_req  \
# 2 2019-12-12 04:54:48+00:00               4               72          1
# ...

# %%
# It seems that nodes_req != processors_req for the same reason for which nodes_req != nodes_used; User options
# Hence we can't drop processors_req and nodes_req.
# One pattern is visible: if processors_req <= 36, nodes_req = 1. If processors_req > 36, nodes_req = 2.
# Hence, if processors_req > K * 36, node_req = K + 1.
# Or, nodes_req = ceil(processors_req / 36).
# Check if the above condition holds true
import math

calculated_nodes_req = df_subset['processors_req'].apply(lambda x: math.ceil(x / 36))
df_subset[df_subset['nodes_req'] != calculated_nodes_req].shape
# Out:
# (4269, 20)

# %%
# Above condition doesnt hold. Analyze.

df_subset1 = df_subset[df_subset['nodes_req'] != calculated_nodes_req]
df_subset1.head()
# Out:
#             user       account      qos  array_pos partition  \
# 8   6C637126FC7B  DED0AFB7AD71  standby        NaN     short
# 16  6C637126FC7B  DED0AFB7AD71  standby        NaN     short
# 52  D2CBEC6D5B32  0AB3AD47AC82  standby        NaN  standard
# 55  A092D098D81A  1D7AE4D8F459   normal        NaN     short
# 56  D2CBEC6D5B32  0AB3AD47AC82  standby        NaN  standard
#
#                  submit_time                start_time    queue_wait  \
# 8  2019-12-03 09:49:39+00:00 2019-12-03 09:50:12+00:00   P0DT0H0M33S
# 16 2019-12-04 18:08:27+00:00 2019-12-04 18:08:33+00:00    P0DT0H0M6S
# 52 2019-12-16 09:26:31+00:00 2019-12-16 09:40:47+00:00  P0DT0H14M16S
# 55 2019-12-15 20:46:02+00:00 2019-12-15 20:46:41+00:00   P0DT0H0M39S
# 56 2019-12-16 09:26:38+00:00 2019-12-16 09:40:47+00:00   P0DT0H14M9S
#
#                     end_time  processors_req  processors_used  nodes_req  \
# 8  2019-12-03 10:45:10+00:00             180              180          1
# ...

# %%
# User options are the reason. Hence, we can drop neither nodes_req nor processors_req.
# Now's let's analyze wallclock_used and cpu_used.
# Before that, convert wallclock_req, wallclock_used and cpu_used into seconds.
# Each string of these fields is as follows: P<Num_days>T<Num_hours><Num_mins><Num_secs>.

import re

def convert_to_seconds(string):
  obj = re.findall('\d+', string)
  seconds = int(obj[0]) * 86400 +  int(obj[1]) * 3600 + int(obj[2]) * 60 + int(obj[3])
  return seconds

for i in ["wallclock_req", "wallclock_used", "cpu_used"]:
  jobs_df[i] = jobs_df[i].apply(convert_to_seconds)

jobs_df.head()
# Out:
#            user       account      qos  array_pos partition  \
# 0  9034779C0D76  CA2FCF3FAD85   normal        NaN       csc
# 1  538894D70272  4E8A31C3E777     high        NaN  standard
# 2  B6BF2D0A9DD5  281BDCFA733D   normal        NaN       gpu
# 3  B6BF2D0A9DD5  281BDCFA733D   normal        NaN       gpu
# 4  23D3EBCDD8DB  EFF4CEEC9899  standby        NaN     short
#
#                 submit_time                start_time    queue_wait  \
# 0 2019-12-04 16:10:02+00:00 2019-12-04 16:10:07+00:00    P0DT0H0M5S
# 1 2019-12-27 07:50:44+00:00 2019-12-27 07:50:59+00:00   P0DT0H0M15S
# 2 2019-12-11 10:58:48+00:00 2019-12-11 16:44:31+00:00  P0DT5H45M43S
# 3 2019-12-12 17:53:07+00:00 2019-12-13 10:56:27+00:00  P0DT17H3M20S
# 4 2019-12-02 16:46:36+00:00 2019-12-02 16:47:11+00:00   P0DT0H0M35S
#
#                    end_time  processors_req  processors_used  nodes_req  \
# 0 2019-12-04 16:17:00+00:00               2               72          2
# ...

# %%
# Check if cpu_used = wallclock_used * 36 * nodes_used

calculated_cpu_used = jobs_df['wallclock_used'] * 36 * jobs_df['nodes_used']
jobs_df[jobs_df['cpu_used'] != calculated_cpu_used].shape
# Out:
# (0, 20)

# %%
# Above condition holds true. We can drop cpu_used.
# Now, check if wallclock_used <= wallclock_req + 10s. This is because Slurm tries to stop the job if it exceeds wallclock_req.

jobs_df[jobs_df['wallclock_used'] > jobs_df['wallclock_req'] + 10].shape
# Out:
# (9222, 20)

# %%
# Above condition does not hold true. Analyze.

df_subset2 = jobs_df[jobs_df['wallclock_used'] > jobs_df['wallclock_req'] + 10]
df_subset2.head()
# Out:
#              user       account      qos  array_pos partition  \
# 5    23A0AEE781F6  EF8C83502275  standby        NaN     short
# 51   23D3EBCDD8DB  EFF4CEEC9899  standby        NaN     short
# 55   A092D098D81A  1D7AE4D8F459   normal        NaN     short
# 140  26D4649C32DD  EF8C83502275  standby        NaN     short
# 179  26D4649C32DD  EF8C83502275  standby        NaN     short
#
#                   submit_time                start_time     queue_wait  \
# 5   2019-12-11 12:36:55+00:00 2019-12-11 12:37:38+00:00    P0DT0H0M43S
# 51  2019-12-13 23:46:27+00:00 2019-12-13 23:52:54+00:00    P0DT0H6M27S
# 55  2019-12-15 20:46:02+00:00 2019-12-15 20:46:41+00:00    P0DT0H0M39S
# 140 2019-11-30 14:00:06+00:00 2019-12-03 00:46:17+00:00  P2DT10H46M11S
# 179 2019-11-30 14:22:13+00:00 2019-12-03 12:37:40+00:00  P2DT22H15M27S
#
#                      end_time  processors_req  processors_used  nodes_req  \
# 5   2019-12-11 16:38:11+00:00             144              144          4
# ...

# %%
# It seems that jobs runs for a variable number of seconds after the time limit before stopping.
# Instead of 10s, let's find the max number of seconds that the job can run after the time limit.
# In Slurm methodology, Time Limit is nothing but wallclock_req.

#jobs_df[jobs_df['wallclock_used'] > jobs_df['wallclock_req'] + 80].shape
#jobs_df[jobs_df['wallclock_used'] > jobs_df['wallclock_req'] + 150].shape
jobs_df[jobs_df['wallclock_used'] > jobs_df['wallclock_req'] + 50000].shape
# Out:
# (0, 20)

# %%
# After quite a lot of experimentation, it seems that all the jobs stop after 80s.
# Another dataset (2020-08), saw this time duration being 50000.
# Jobs that exceed time limit have their states marked as TIMEOUT.
# Let's verify if the above condition holds true.

df_subset3 = jobs_df[jobs_df['wallclock_used'] > jobs_df['wallclock_req']]
df_subset3[df_subset3['state'] != "TIMEOUT"].shape
# Out:
# (2, 20)

# %%
# Above condition does not hold for only two records. Analyze.

weird_jobs = df_subset3[df_subset3['state'] != "TIMEOUT"]
weird_jobs
# Out:
#                 user       account      qos  array_pos partition  \
# 86332   DBB6286EDAC0  E2101C558519   normal        NaN     short
# 134885  23D3EBCDD8DB  EFF4CEEC9899  standby        NaN     short
#
#                      submit_time                start_time    queue_wait  \
# 86332  2019-12-13 14:24:09+00:00 2019-12-13 14:26:04+00:00   P0DT0H1M55S
# 134885 2019-12-20 12:19:39+00:00 2019-12-20 16:47:28+00:00  P0DT4H27M49S
#
#                         end_time  processors_req  processors_used  nodes_req  \
# 86332  2019-12-13 15:26:22+00:00               1               36          1
# 134885 2019-12-20 20:47:30+00:00              36               36          1
#
#         nodes_used   nodelist  wallclock_req  wallclock_used  cpu_used  \
# 86332            1  [r2i6n19]           3600            3618    130248
# 134885           1  [r6i5n12]          14400           14402    518472
#
#         std_power  avg_power   state
# 86332   105.91501  297.66666  FAILED
# ...

# %%
# The above jobs have failed. They are a special case of TIMEOUT since after exceeding the time limit, they failed, while the rest were stopped by Slurm.
# Sometimes, jobs can complete or be cancelled after timeout. (2020-08).
# We drop wallclock_used not only because it can be obtained only after the end of a job, but also that in most cases it is less than wallclock_req.
# std_power and avg_power are measured during the execution of a job.
# The measurements are taken at periodic intervals in the duration when a job runs.
# Hence, from the point of submission time or even allocation time, these metrics cannot be obtained.
# Let's drop all the columns that were identified for removal so far.

jobs_df.drop(columns=['processors_used', 'cpu_used', 'wallclock_used', 'std_power', 'avg_power'], inplace=True)
jobs_df.head()
# Out:
#            user       account      qos  array_pos partition  \
# 0  9034779C0D76  CA2FCF3FAD85   normal        NaN       csc
# 1  538894D70272  4E8A31C3E777     high        NaN  standard
# 2  B6BF2D0A9DD5  281BDCFA733D   normal        NaN       gpu
# 3  B6BF2D0A9DD5  281BDCFA733D   normal        NaN       gpu
# 4  23D3EBCDD8DB  EFF4CEEC9899  standby        NaN     short
#
#                 submit_time                start_time    queue_wait  \
# 0 2019-12-04 16:10:02+00:00 2019-12-04 16:10:07+00:00    P0DT0H0M5S
# 1 2019-12-27 07:50:44+00:00 2019-12-27 07:50:59+00:00   P0DT0H0M15S
# 2 2019-12-11 10:58:48+00:00 2019-12-11 16:44:31+00:00  P0DT5H45M43S
# 3 2019-12-12 17:53:07+00:00 2019-12-13 10:56:27+00:00  P0DT17H3M20S
# 4 2019-12-02 16:46:36+00:00 2019-12-02 16:47:11+00:00   P0DT0H0M35S
#
#                    end_time  processors_req  nodes_req  nodes_used  \
# 0 2019-12-04 16:17:00+00:00               2          2           2
# ...

# %%
# We can additionally drop end_time since its not required by JSP.
# queue_wait is the difference between start_time and submit_time; we can drop queue_wait too.

jobs_df.drop(columns=['end_time', 'queue_wait'], inplace=True)
jobs_df.head()
# Out:
#            user       account      qos  array_pos partition  \
# 0  9034779C0D76  CA2FCF3FAD85   normal        NaN       csc
# 1  538894D70272  4E8A31C3E777     high        NaN  standard
# 2  B6BF2D0A9DD5  281BDCFA733D   normal        NaN       gpu
# 3  B6BF2D0A9DD5  281BDCFA733D   normal        NaN       gpu
# 4  23D3EBCDD8DB  EFF4CEEC9899  standby        NaN     short
#
#                 submit_time                start_time  processors_req  \
# 0 2019-12-04 16:10:02+00:00 2019-12-04 16:10:07+00:00               2
# 1 2019-12-27 07:50:44+00:00 2019-12-27 07:50:59+00:00               1
# 2 2019-12-11 10:58:48+00:00 2019-12-11 16:44:31+00:00               4
# 3 2019-12-12 17:53:07+00:00 2019-12-13 10:56:27+00:00               4
# 4 2019-12-02 16:46:36+00:00 2019-12-02 16:47:11+00:00              36
#
#    nodes_req  nodes_used            nodelist  wallclock_req      state
# 0          2           2  [r2i5n12, r2i5n13]           1800     FAILED
# ...

# %%
# The above experiments were repeated with two other datasets from NREL: 2020-04 and 2020-08.
# Most of the observations held true. Few differences have been marked in the respective cell's comments.
# Obtain the value_counts for the state column.


jobs_df['state'].value_counts()
# Out:
# state
# COMPLETED        162221
# TIMEOUT           11975
# FAILED             5105
# CANCELLED          2107
# NODE_FAIL            61
# OUT_OF_MEMORY        34
# Name: count, dtype: int64

# %%
# Find 25, 50, 75 percentiles and the mean of the waiting time in the queue
# The third dataset had all these values less than 6h 30m
queue_wait = jobs_df['start_time'] - jobs_df['submit_time']
queue_wait.quantile(0.25), queue_wait.quantile(0.5), queue_wait.quantile(0.75), queue_wait.mean()
# Out:
# (Timedelta('0 days 02:01:00'),
#  Timedelta('0 days 10:12:09'),
#  Timedelta('0 days 20:59:53'),
#  Timedelta('0 days 18:01:27.641840630'))

# %%
# Download the 2023 Eagle Jobs Dataset

! wget https://data.openei.org/files/5860/eagle_data.csv.bz2
# Out:
# --2025-04-05 17:20:21--  https://data.openei.org/files/5860/eagle_data.csv.bz2
# Resolving data.openei.org (data.openei.org)... 44.231.39.234, 50.112.26.156, 34.210.45.45, ...
# Connecting to data.openei.org (data.openei.org)|44.231.39.234|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 115605724 (110M) [application/octet-stream]
# Saving to: ‘eagle_data.csv.bz2’
#
# eagle_data.csv.bz2  100%[===================>] 110.25M  78.2MB/s    in 1.4s
#
# 2025-04-05 17:20:23 (78.2 MB/s) - ‘eagle_data.csv.bz2’ saved [115605724/115605724]

# %%
# obtain dataframe for 2023 Eagle Jobs

new_jobs_df = pd.read_csv('eagle_data.csv.bz2')
new_jobs_df.head()
# Out:
#    job_id      user      account     partition      qos  wallclock_req  \
# 0  459053  user0001  account0001  partition001  Unknown          240.0
# 1  459058  user0001  account0001  partition001  Unknown          300.0
# 2  459059  user0001  account0001  partition002  Unknown        36000.0
# 3  459062  user0001  account0001  partition001  Unknown          300.0
# 4  459061  user0001  account0001  partition001  Unknown         3660.0
#
#    nodes_req  processors_req  gpus_req  mem_req          submit_time  \
# 0        256            9216         0      0.0  2018-11-14 13:26:16
# 1          1               1         0      0.0  2018-11-14 13:26:16
# 2        180             360         0      0.0  2018-11-14 13:26:16
# 3          1               1         0      0.0  2018-11-14 13:26:16
# 4        180             360         0      0.0  2018-11-14 13:26:16
#
#             start_time             end_time  run_time      state  \
# ...

# %%
# Convert submit_time and start time to datetime columns.
new_jobs_df['submit_time'] = pd.to_datetime(new_jobs_df['submit_time'])
new_jobs_df['start_time'] = pd.to_datetime(new_jobs_df['start_time'])
new_jobs_df['end_time'] = pd.to_datetime(new_jobs_df['end_time'])

# %%
# Find 25, 50, 75 percentiles and the mean of the waiting time in the queue

queue_wait = new_jobs_df['start_time'] - new_jobs_df['submit_time']
queue_wait.quantile(0.25), queue_wait.quantile(0.5), queue_wait.quantile(0.75), queue_wait.mean()
# Out:
# (Timedelta('0 days 00:03:30'),
#  Timedelta('0 days 01:30:22'),
#  Timedelta('0 days 10:26:28'),
#  Timedelta('0 days 19:45:50.320237758'))

# %%
# Find 25, 50, 75 percentiles and the mean of the run time.
run_time = new_jobs_df['end_time'] - new_jobs_df['start_time']
run_time.quantile(0.25), run_time.quantile(0.5), run_time.quantile(0.75), run_time.mean()
# Out:
# (Timedelta('0 days 00:00:28'),
#  Timedelta('0 days 00:05:38'),
#  Timedelta('0 days 01:10:05'),
#  Timedelta('0 days 02:23:33.672024611'))
